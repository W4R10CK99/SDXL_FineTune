# %% [markdown]
# <a href="https://colab.research.google.com/github/W4R10CK99/SDXL_FineTune/blob/main/trainedWeightsTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers

# %%
from diffusers import DiffusionPipeline
import torch

# %%
# !pip install -U autotrain-advanced

# %%
# !pip install accelerate

# %%
prj_path = "/content/my-dreambooth-project"
model = "stabilityai/stable-diffusion-xl-base-1.0"
pipe = DiffusionPipeline.from_pretrained(
    model,
    torch_dtype=torch.float16,
)
pipe.to("cuda")
pipe.load_lora_weights(prj_path, weight_name="StableDiffusionViratKohli.safetensors")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "photo of Virat Kohli wearning sunglasses in garden, 4k, ultra realistic"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25).images[0]
  image
  image.save(f"GenImages/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "photo of Virat Kohli riding superbike, 4k, ultra realistic"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25).images[0]
  image
  image.save(f"GenImages/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "photo of Virat Kohli playing cricket, 4k, ultra realistic"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25).images[0]
  image
  image.save(f"GenImages/{seed}.png")
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
def displayImg(path):
  image_folder_path = path
  image_files = [f for f in os.listdir(image_folder_path) if os.path.isfile(os.path.join(image_folder_path, f))]

  num_rows = 1
  num_columns = 3

  # Create a new figure with appropriate dimensions
  plt.figure(figsize=(10, 7.5))

  # Display images
  for i, image_file in enumerate(image_files, start=1):
      # Load image
      img_path = os.path.join(image_folder_path, image_file)
      img = Image.open(img_path)

      # Add subplot
      plt.subplot(num_rows, num_columns, i)

      # Display image
      plt.imshow(img)
      plt.axis('off')  # Hide axis

  plt.show()

# %%
displayImg('/content/GenImages')

# %%
prompt = "photo of Virat Kohli riding a bull in farms, 4k,realistic, nature, vibrant colors, natural blur"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25).images[0]
  image
  image.save(f"GenImages/{seed}.png")

displayImg('/content/GenImages')
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "photo of Virat Kohli riding a bull in farms, 4k,realistic, nature, vibrant colors, natural blur"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25).images[0]
  image
  image.save(f"GenImages/{seed}.png")

displayImg('/content/GenImages')
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "photo of Virat Kohli in apple farm, 4k,realistic, nature, vibrant colors, natural blur"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25).images[0]
  image
  image.save(f"GenImages/{seed}.png")

displayImg('/content/GenImages')
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
prompt = "photo of Virat Kohli as army personnel, 4k,realistic, natural blur"
neg="easynegative, human, lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worstquality, low quality, normal quality, jpegartifacts, signature, watermark, username, blurry, bad feet, cropped, poorly drawn hands, poorly drawn face, mutation, deformed, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, extra fingers, fewer digits, extra limbs, extra arms,extra legs, malformed limbs, fused fingers, too many fingers, long neck, cross-eyed,mutated hands, polar lowres, bad body, bad proportions, gross proportions, text, error, missing fingers, missing arms, missing legs, extra digit, extra arms, extra leg, extra foot"

for seed in range (2):
  generator = torch.Generator("cuda").manual_seed(seed)
  image = pipe(prompt=prompt, generator=generator,num_inference_steps=25,negative_prompt=neg).images[0]
  image
  image.save(f"GenImages/{seed}.png")

displayImg('/content/GenImages')
# Out:
# ...
#   0%|          | 0/25 [00:00<?, ?it/s]
